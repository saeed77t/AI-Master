# %%
import numpy as np
import random as rnd

# %%
InputEq = 'x*x+x+x+1'

# %%
Terminalset = ['x','1','2','3','4','5','6','7','8','9','x','x','x','x','x','x','x','x','x','x']
Functionset = ['*','/','+','-']
pra = ['(' , ')']
numberset = rnd.sample(range(20, 200), 30)

# %%
def InitalEq(terminal , function):
    flor = 1
    ciel = 15
    
    chosen = rnd.randrange(flor , ciel,2)
    
    right = rnd.choice(terminal)
    oprand = rnd.choice(function)
    lend = chosen
    result = ""
    flag = 1
    probability = rnd.randint(0,100)
    if(probability<10):
        result = rnd.choice(terminal)
        chosen = 1 
        return result
    
    while(lend > 0):
        left = rnd.choice(terminal) 
        right = rnd.choice(terminal)
        oprand = rnd.choice(function)
        if(flag == 1):
            
            result = result+"("+str(left) +str(oprand) +  str(right)+")"
            lend = lend-3
            flag = 0 
        else:
            p = rnd.randint(1,100)
            
            if(p>0 and p<5):
                a = "("+ str(left) + str(oprand) + str(right)+")"
                lr = str(rnd.choice(terminal))
                opr = str(rnd.choice(function))
                b = opr+"("+lr+opr+a+")"
                result = result + b
            elif(p>15 and p<30):
                a = "("+ str(left) + str(oprand) + str(right)+")"
                lr = str(rnd.choice(terminal))
                opr = str(rnd.choice(function))
                b = opr+"("+a+opr+lr+")"
                result = result + b
            elif(p>31 and p<39):
                a = "("+ str(left) + str(oprand) + str(right)+")"
                lr = str(rnd.choice(terminal))
                opr = str(rnd.choice(function))
                b = opr+"("+a+opr+lr+")"
                result = "("+result +b+")"
            else:
                a = str(oprand)+"("+ str(left) + str(oprand) + str(right)+")"
                result = result + a
            lend = lend-4
    if(len(result)>7):
        result = "("+result+")"
            
            
    return result

# %%
def CalcFitness(inputs,pop,numberset):

    #create needs
    inputans = []
    popans = [[0 for i in range(len(numberset))] for j in range(len(pop))]
    #calculate the output of input with the 50 numberset
    for i in range(len(numberset)):
        x = numberset[i]
        inputans.append( eval(inputs))
        
    #calculate the output of the population with the 50 number set 
    for i in range(len(pop)):
        for j in range(len(numberset)):
            x = numberset[j]
            try:
                 popans[i][j] = eval(pop[i][0])
            except ZeroDivisionError:
                popans[i][j] = None
    

    #calculate the fitness of the population 
    counter = 0
    for i in range(len(popans)):
        for j ,w  in zip(popans[i] , inputans):
            if( j == w ):
                counter = counter +1
                    
        pop[i][1] = int(counter)
        counter = 0

   #penalty of fitness if fitness is too big 
    counted = len(inputs)
    cnt = 0
    for i in range(len(pop)):
        for j in (pop[i][0]):
            if(j !='(' and j !=')'):
                cnt +=1
        if(cnt > counted and pop[i][1]>15 ):        
            pop[i][1] = int(pop[i][1]) - cnt
        cnt=0
        
    #type cast fitness      
    for i in range(len(pop)):
        pop[i][1] = int(pop[i][1])
    #sort fitness 
    pop = sorted(pop,key=lambda t: t[1],reverse=True)
    return pop

# %%
def ParentSelection(population):
    n = len(population)
    p = n*16/100
    r = int(n) - int(p)
    g1 = []
    g2=[]
    
    prob = rnd.randint(1,100)
    for i in range(int(p)):
        g1.append ( population[i])
    for i in range(int(p) ,n):
        g2.append (population[i])
        
    if(prob < 80):
        
        index = rnd.sample(range(0,int(p-1)),5)
        parent = g1[min(index)]
    else:
        index = rnd.sample(range(0,int(r-1)),5)
        parent = g2[min(index)]
        
    return parent

# %%
def CutBox(p,terminal,function):
    n = len(p)
    # print(p)
    select = rnd.randint(1,n-1)
    if(n<3):
        return p
    if(p[select]in function and p[select+1] == ')' and p[select-1] in terminal and p[select-2]=='(' ):
        return select +1
    if(p[select] in function and p[select+1] in terminal and  p[select-1]== ')' ):
        return select+1
    if(p[select] in function and p[select-1] in terminal and p[select+1] == '('):
        return select+1    
    if(p[select] in function and p[select-1] == ')' and p[select+1] == '('):
        return select +1
    if(p[select] in function and p[select+1] in terminal and p[select-1] in terminal  and p[select-2] == '('  and p[select-3] == '(' and p[select+2] == ')'  and p[select+3] == ')'):
        return select +1
        
    else:
        return CutBox(p,terminal,function)

# %%
def Xover(parent1,parent2,terminal,function):
    p1 = [*parent1[0]]
    p2= [*parent2[0]]
    n1 = len(parent1[0])
    n2 = len(parent2[0])
    if(n1==1):
        part1=parent1[0]+rnd.choice(function)
        part2=parent1[0]
    elif(n1 == 5):
        part1 = parent1[0][1:3]
        part2 = parent1[0][3:n1-1]
    else:
        
        point1 = CutBox(p1,terminal,function)
        part1=parent1[0][1:point1]
        part2=parent1[0][point1:n1-1]
        nn1 = len(part1)
        nn2 = len(part2)
            
            
    if(n2==1):
        part3=parent2[0]+rnd.choice(function)
        part4=parent2[0]
    elif(n2 == 5):
        part3 = parent2[0][1:3]
        part4 = parent2[0][3:n2-1]
    else:
       
        point2 = CutBox(p2,terminal,function)
        part3=parent2[0][1:point2]
        part4=parent2[0][point2:n2-1]


    # print('part1: ', part1)
    # print('part2: ',part2)
    # print('part3: ',part3)
    # print('part4: ',part4)
    child1 = part1+part4
    child2 = part3+part2
    # print('child1: ' ,child1 )
    # print('child2: ', child2)
    
    #control number of pranthesessfor child 1 
    c1o = 0
    c1c = 0
    for i in range(len(child1)):
        # if(child1[i] in terminal and child1[i+1] not in function):
        #     child1[i]
        
        if(child1[i]=='('):
            c1o +=1
        if(child1[i]==')'):
            c1c +=1
            
            
    if(c1o-c1c!=0):
        if(c1o>c1c):
            c = c1o-c1c
            for i in range(c):
                child1 = child1+')'
        if(c1o<c1c):
            c = c1c - c1o
            for i in range(c):
                child1 = '('+child1
            
    #control number of pranthesess for child 2
    c2o = 0
    c2c = 0
    for i in range(len(child2)):
        if(child2[i]=='('):
            c2o +=1
        if(child2[i]==')'):
            c2c +=1
            
            
    if(c2o-c2c!=0):
        if(c2o>c2c):
            c = c2o-c2c
            for i in range(c):
                child2 = child2+')'
        if(c2o<c2c):
            c = c2c - c2o
            for i in range(c):
                child2 = '('+child2
                
                
    if(len(child1)>=3):
        child1 = "("+child1+")"         

    if(len(child2)>=3):
        child2 = "("+child2+")"         
        
    child1 = [child1 , 0] 
    child2 = [child2 , 0] 
    return child1 , child2

# %%
def mutation(parent,terminal , function):
    n = len(parent[0])
    p = [*parent[0]]
    select = rnd.randint(0,n-1)
    
    if(parent[0][select] in terminal):
        
        p[select] = rnd.choice(terminal)
        
        s =''.join(p)
        # print(s)
        parent[0] = s
        return parent
        
        
    elif(parent[0][select] in function):
        
        p[select] = rnd.choice(function)
        s=''.join(p)
        # print(s)
        parent[0] = s
        return parent
        
    else:
        return mutation(parent,terminal , function)

# %%
def SurvivalSelection(children , population ):
    x = len(population)
    perc = int(x*2/100)
    elite = []
    n = len(children)
    for i in range(perc):
        elite.append(population[i])
        
    for i in reversed (range(n-perc,n)):
        del children[i]
        
    for i in range(len(elite)):
        children.append(elite[i])
        
    #sort fitness 
    children = sorted(children,key=lambda t: t[1],reverse=True)
    
    return children

# %%
#initail first population
pop = [[0 for i in range(2)] for j in range(2000)]

for i in range(2000):
    equation= InitalEq(Terminalset,Functionset)
    pop[i][0]=(equation)

# %%
# for i in range(len(population)):
#     if(int(population[i][1]) > 0):
#         print(population[i])

# %%
population = CalcFitness(InputEq , pop , numberset)

# %%
for i in range(1000):
    children = []
    while(len(children)<2000):
        prob = rnd.randint(0,100)
        if(prob>5):
            parent1 = ParentSelection(population)
            parent2=ParentSelection(population)
            child1 , child2 = Xover(parent1,parent2,Terminalset,Functionset)
            children.append(child1)
            children.append(child2)
        else:
            parent = ParentSelection(population)
            child = mutation(parent,Terminalset , Functionset)
            children.append(child)
    children =  CalcFitness(InputEq , children , numberset)
    population = SurvivalSelection(children , population )
    if(population[i][1]==30):
        print('soloution found in itration  : ',i, population[i])
        break
    if(i%20 == 0):
        print('Itration :', i ,'rank1 = ', population[i])
# Out:
# Itration : 0 rank1 =  ['((x/x)-(7-8)*(x*x)+(x+x))', 15]
# soloution found in itration  :  6 ['((1+(x*x)+(x+x)))', 30]

# %%
population
# Out:
# [['((1+(x*x)+(x+x)))', 30],
#  ['((1+(x*x)+(x+x)))', 30],
#  ['((1+(x*x)+(x+x)))', 30],
#  ['((1+(x*x)+(x+x)))', 30],
#  ['((1+(x*x)+(x+x)))', 30],
#  ['(((1+(x*x)+(x+x))))', 30],
#  ['((1+(x*x)+(x+x)))', 30],
#  ['((1+(x*x)+(x+x)))', 30],
#  ['((1+(x*x)+(x+x)))', 30],
#  ['((1+(x*x)+(x+x)))', 30],
#  ['(((1+(x*x)+(x+x))))', 30],
#  ['((1+(x*x)+(x+x)))', 30],
#  ['((1+(x*x)+(x+x)))', 30],
#  ['(((x+(x*x)+(x+1))))', 30],
#  ['((1+(x*x)+(x+x)))', 30],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((((x/x)+(x*x)+(x+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((((x/x)+(x*x)+(x+x)))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((((x/x)+(x*x)+(x+x)))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((((x/x)+(x*x)+(x+x)))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((((x/x)+(x*x)+(x+x)))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((((x/x)+(x*x)+(x+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x/x)+(x*x)+(x+x))', 19],
#  ['((x/x)+(x*x)+(x+x))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((((x/x)+(x*x)+(x+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((((x/x)+(x*x)+(x+x)))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((((x/x)+(x*x)+(x+x)))))', 19],
#  ['(((x+(x/x)+((x*x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((((x/x)+(x*x)+(x+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((((x/x)+(x*x)+(x+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x/x)+(x*x)+(x+x))', 19],
#  ['((x/x)+(x*x)+(x+x))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x/x)+(x*x)+(x+x)))', 19],
#  ['(((x+(x*x)+((x/x)+x))))', 19],
#  ['((x+(x*x)+((x/x)+x)))', 19],
#  ['(((x+(x*x)+((x/x)+(x/1)))))', 17],
#  ['(((x+(x*x)+((x/x)+(x*1)))))', 17],
#  ['((x+(x*x)+((x/x)+(x/1))))', 17],
#  ['(((x-x)-(7-8)+(x*x)+(x+x)))', 15],
#  ['((((((x-x)+x)+(x*x)+((x/x)+x)))))', 15],
#  ['(((x-x)-(7-8)+(x*x)+(x+x)))', 15],
#  ['(((x-x)-(7-8)+(x*x)+(x+x)))', 15],
#  ['(((((x-x)+x)+(x*x)+((x/x)+x))))', 15],
#  ['((x+(x*x)+(x-x)+((x/x)+x)))', 15],
#  ['(((x+(x*x)+((x/x)+x))))', 8],
#  ['(((x+(x*x)+((x/x)+x))))', 8],
#  ['(((x+(x*x)+((x/x)+x))))', 8],
#  ['(((((x-x)+x)+(x*x)+(x*x)+(x+x))))', 0],
#  ['((((x/x)+((x/x)+x))))', 0],
#  ['(((x/x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+(x+3)))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['(((1+(x*x)+x)))', 0],
#  ['(((x+(x+x))))', 0],
#  ['(((1+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x/x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['((((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x+x))))', 0],
#  ['((((x/x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+(x+x))))', 0],
#  ['(((x/x)+(x*x)+(x*x)+(x+x)))', 0],
#  ['((1+(x+x)))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+4))))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['(((x+1)))', 0],
#  ['((((x/x)/(x*x)+(x+x))))', 0],
#  ['((((x/x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+(x+x)))))', 0],
#  ['(((((x/x)+(x*x)+x))))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+1)))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+(x+x))))', 0],
#  ['((((x/x)+x)))', 0],
#  ['(((x+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((((x+(x+x)))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+(x*x)+((x/x)+x)))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['((x+(x*3)+((x/x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['(((1+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x/x)+(x*x)+((x/x)+((x-5)*((x*x)/((x*x)/(2-x)-(9-x)*5))))))', 0],
#  ['(((x+(x*x)+(5+9)*((x/x)+x))))', 0],
#  ['(((x+(x*x)+((2-x)/(x*x)+((x/x)+x)))))', 0],
#  ['((((x+(x*x)+(x*x)+(x+x)))))', 0],
#  ['((x+(x*x)+(x/8)))', 0],
#  ['(((x-x)+((x/x)+x)))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['(((x+(5+9)*((x-5)*((x/x)+x)))))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x+(x*x)+(7-8)*(5-6)+(x-8))))', 0],
#  ['((((8*4)-(5/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((((x-x)-((x/x)+x))))', 0],
#  ['((((1+(x*x)+x))))', 0],
#  ['(((x-(x*x)+((x/x)+(x+x)))))', 0],
#  ['(((((x/x)+(x*x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x+x)))))', 0],
#  ['(((x-(x*x)+x)))', 0],
#  ['((((x/x)+(x*x)+(7-8)+2)))', 0],
#  ['(((x+(x+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x-x)-(7-8)-(x*x)+(x+x))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+((x/x)+x)))))', 0],
#  ['((((x+x))))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x/8)))', 0],
#  ['(((x+6)))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x+x))))', 0],
#  ['((((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['((((x+1))))', 0],
#  ['(((x-((9+3)+(x*x)+((x/x)+x)))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/5)+2)))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+(x*x)+(x*x)+((x/x)+x)))))', 0],
#  ['(((((x/x)+x))))', 0],
#  ['((((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+(x+x))))', 0],
#  ['((x+(x-x)+5))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['((1+(x*x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x+(x/8))))', 0],
#  ['((((x*x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+(x+x))))', 0],
#  ['(((1+x)))', 0],
#  ['(((x/x)/(x*x)+(x+x)))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+1)))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['(((x-x)-(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['(((x+(x*x)+(x+x))))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((((x/x)+(x*x)+x)))', 0],
#  ['(((x+(x*x)+(x+x))))', 0],
#  ['(((((5+(2-x)-(9-x)*5)))))', 0],
#  ['(((((1*x)-((x/x)+x)))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['((((x/x)+(x*x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['((1+((x/x)+x)))', 0],
#  ['((((x-x)-(7-8)+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+x))))', 0],
#  ['((x+(x+x)))', 0],
#  ['(((x/x)+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['(((((x/x)+x))))', 0],
#  ['(((x+((x/x)+(x*x)+(x+x)))))', 0],
#  ['(((1+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x+x))))', 0],
#  ['(((1+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['((x+(x/x)-((x/x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['(((x+x)))', 0],
#  ['((((x/x)+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['(((x/x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+((9/x)-x)))', 0],
#  ['(((x+(x+x))))', 0],
#  ['((((x/x)+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['((((x/x)+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['((x+(x+x)))', 0],
#  ['(((x/x)+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x+x)-(x+7)/(x+x)))', 0],
#  ['(((x+(x/x))))', 0],
#  ['((x-x)+(5+9)*((x-5)*((x*x)/(x*x)+((x/x)+x))))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x+x))))', 0],
#  ['((x/(x*x)+(x+x)))', 0],
#  ['(((x/x)+((x/x)+x)))', 0],
#  ['((((x/x)+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['((x/x)-((x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['(((x/x)+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+(x+x)))', 0],
#  ['((x+x))', 0],
#  ['(((8-x)-(x*x)+(x*x)+((x/x)*((x/x)+x))))', 0],
#  ['((((1+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+(x+x)))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/9)+1)))', 0],
#  ['(((x+7)))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)-((x/9)+7)))', 0],
#  ['(((x/x)+((x+x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x/x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+(x+x)))))', 0],
#  ['(((((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+(x+x)))))', 0],
#  ['(((((x/x)+x))))', 0],
#  ['((x+(x/x)-((x/x)+x)))', 0],
#  ['(((1+(x+x))))', 0],
#  ['(((x+(x*x)+(x*x)+(x+x))))', 0],
#  ['(((x+(7-8)+(x*x)+(9-x)*(x*8)/(x+x))))', 0],
#  ['(((x+(x+x))))', 0],
#  ['((((x/x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+6)))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['(((1+(x*x)+x)))', 0],
#  ['((x+(3*x)+((x/x)+x)))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+(x+x)))))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+(x*x)+(2-x)-(x*x)+(x/x))))', 0],
#  ['((((1*x)-((x/x)+x))))', 0],
#  ['(((x+(x+x))))', 0],
#  ['((((x/x)+(x*x)+(x-1))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x/8)))))', 0],
#  ['(((((x/x)+(x*x)+(x/x)))))', 0],
#  ['(((1+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x+x))))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['((((x*4)-(x*x)+((x/x)+(x*x)+(x+x)))))', 0],
#  ['(((((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['((((1*x)-(x+x)/x)))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x/x)/((x/x)+(x*x)+(x+x))))', 0],
#  ['(((1+x)))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x/x)+(x*x)+(x+2)))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['((x/x)+((7*x)+(x*x)-(x*x)+((x/x)+x)))', 0],
#  ['(6*(x*x)+(x+x))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x+(x*x)+(x+x))))', 0],
#  ['((((8-x)-((x/x)+x))))', 0],
#  ['(((x/x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x+3)))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+(x+x)))))', 0],
#  ['(((((x/x)+x))))', 0],
#  ['(((1+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x+x))))', 0],
#  ['((((x/x)+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x+x))))', 0],
#  ['((x+(x*x)+(x-8)+(x*x)+(x+x)))', 0],
#  ['(((x/x)+((x/x)+x)))', 0],
#  ['((((x/x)+(x+x))))', 0],
#  ['((((x+x)/(x*x)+x)))', 0],
#  ['((((x/x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+(x+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['((((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+x))', 0],
#  ['(((x+x)-((x/x)+x)))', 0],
#  ['((x+(x-x)))', 0],
#  ['(((x+x)-(x*x)+(3*x)+((x/x)+x)))', 0],
#  ['((x+((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((((x-x)-(x*x)+((x/x)+x))))', 0],
#  ['(((x-((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+x)))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['((((x/(x*x)+((x/x)+x)))))', 0],
#  ['((((x+x))))', 0],
#  ['((((x-x)-(x-8)+(x-1))))', 0],
#  ['(((x+(x*x)+((x*x)+x))))', 0],
#  ['((1+(x*x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+((x/x)+x)))))', 0],
#  ['((((x+x))))', 0],
#  ['((1+(x*x)+x))', 0],
#  ['(((x-x)-(7-8)+(7-8)+(x*x)+(x+x)))', 0],
#  ['(((x+(x*x)+1)))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x/x)+(x*x)+(x*x)+(x+x)))', 0],
#  ['((1+(x+x)))', 0],
#  ['(((x+(x+x))))', 0],
#  ['((((9*x)-(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['((((x/x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['(((x+(x*x)+(x*x)+(x+x))))', 0],
#  ['((((x/x)+((x/x)+x))))', 0],
#  ['((((1+(x*x)+(x/x)))))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((((1+x))))', 0],
#  ['(((x/(x*x)+((x/x)+(x*x)+(x+x)))))', 0],
#  ['(((x+(x*x)+((x/x)+(x+x)))))', 0],
#  ['(((((x/x)+(x*x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['((((1+(x*x)+(x/x)))))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x/x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*8)/x)))', 0],
#  ['((x+(x*x)+((x/x)+((x-x)*(x-x)))))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((x-((x/1)+((x/x)+((x/x)+x)))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['(((1+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x-x)-(7-8)+(x*x)+(x*x)+(x+x)))', 0],
#  ['((1+(x*x)+((x/x)+x)))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((((((x*x)/((x/x)+x))))))', 0],
#  ['(((((x+(x*x)+x)))))', 0],
#  ['(((1+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+(x+x))))', 0],
#  ['(((x+(x*x)+(5+9)*((x-5)*((x*x)/((x*x)/(2-x)-x))))))', 0],
#  ['(((((x+(x*x)+((x/x)+(9-x)*5))))))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['(((x+x)+((x/x)+x)))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+((x/x)+x)))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['((((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+((x/x)+x)))))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+(x+x))))', 0],
#  ['(((x/x)+(x+7)/(x*x)+((x/x)+x)))', 0],
#  ['((x+9))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['(((1+(x+x)/(x*x)+5)))', 0],
#  ['((((1*x)-(x*x)+(x+x))))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+((x/x)+x)))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((((x*x)*(7-8)+(x*x)+((x/x)+x))))', 0],
#  ['(((x-x)-(x-8)+(x*x)+x))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['(((x/x)+((x+x)+(x*x)+(x+x))))', 0],
#  ['((((x/x)+x)-((x/9)+7)))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+((x/x)+x)))))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+(x-x)))', 0],
#  ['(((1*x)-((x/x)+x)))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+(x+x)))))', 0],
#  ['((((x+x))))', 0],
#  ['(((1+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+(x+x))))', 0],
#  ['(((x-x)-(x*x)+(x+x)))', 0],
#  ['((1+(x*x)+((x/x)+x)))', 0],
#  ['((((x+x))))', 0],
#  ['(((x/x)+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+(x+x)))', 0],
#  ['((((x+(x*x)+(x/x)))))', 0],
#  ['((x+(7-8)+(x*x)+(x+x)))', 0],
#  ['(((x-x)-(x*x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['(((x+(x+x))))', 0],
#  ['((((x/x)/(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+(x*x)+(x*x)+(x+x))))', 0],
#  ['((((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['((((x/x)+(x*x)+x)))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+((x/x)+x)))))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+(x*x)+(x*x)+(x/1))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x+x)))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['((((x/x)+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x+x))))', 0],
#  ['((((x/x)+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['(((x+x)-(x+7)/(x*x)+((x/x)+x)))', 0],
#  ['((x+(x+x)))', 0],
#  ['(((((x-x)-((x/x)+x)))))', 0],
#  ['(((((x+x)+x))))', 0],
#  ['(((x+(x*x)+(x+x))))', 0],
#  ['((((x/x)+x)))', 0],
#  ['(((x+((x/x)+((x/x)+x)))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['((((x/x)+(7-8)+((x/x)+x))))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['((((x/x)+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['(((((x/x)+(x*x)+(x/x)))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['((((x-x)+x)))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['((((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x*x)+(x+x))))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['(((1+((x/x)+x))))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x-x)-((x*x)+x)))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+(x+x)))))', 0],
#  ['(((((x/x)+x))))', 0],
#  ['(((x+4)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['((((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((((x+(x*3)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x+(x+x))))', 0],
#  ['(((1+(x*x)+(x*x)+x)))', 0],
#  ['(((x-x)-(x-8)+((x/x)+x)))', 0],
#  ['(((x/x)+(x*x)+x))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['((((x/x)+(x*x)+x)))', 0],
#  ['((((x/x)+(x*x)+x)))', 0],
#  ['((x+((x/x)+(x+x))))', 0],
#  ['(((x/x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+(x*x)+(x+x)))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((((x/x)+(x*x)+x))))', 0],
#  ['((((x*x)*((x/x)+(x+x)))))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+((x/x)+x)))))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+x))))', 0],
#  ['((((x+x))))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((((x/x)+x)))', 0],
#  ['((1+(x*x)+(x+1)))', 0],
#  ['((((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['(((x+x)+((x/x)+x)))', 0],
#  ['((x+(x+2)))', 0],
#  ['(((x/x)+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['(((((x-x)-x))))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['((1+((x/x)+x)))', 0],
#  ['((((x/x)+(x*x)+(x+x)/x)))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((((x/x)+(x*x)+(x*x)+(x*x)+(x+x))))', 0],
#  ['(((x+(x+x))))', 0],
#  ['(((x/x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+(x*x)+(x+x))))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['(((x/x)+1))', 0],
#  ['(((x+(x*x)+(x+x))))', 0],
#  ['(((1+(x*x)+((x/x)+x))))', 0],
#  ['(((((x/x)+x))))', 0],
#  ['((((x-x)-(7-8)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+2)))', 0],
#  ['(((x+(x*x)+(x*x)+x)))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x/x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+(x*x)+(x+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+(x+x))))', 0],
#  ['((((x/x)+x)))', 0],
#  ['(((x+(x*x)+((x/x)+(x+x)))))', 0],
#  ['(((((x/x)+(x*x)+x))))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((((x/x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+(x+x)))))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+((x/x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['(((x+(x*x)+(x+x))))', 0],
#  ['(((x-(7-8)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+(x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['(((x/x)+(x*x)+(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x+x)))', 0],
#  ['(((x+(x*x)+((x/x)+(2/x)+5))))', 0],
#  ['((((x+x))))', 0],
#  ['(((x/x)+(x/1)))', 0],
#  ['((1+(x+x)))', 0],
#  ['((x+(x*x)+(x*x)+(x*x)+(x+1)))', 0],
#  ['(((x+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+(x+2)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['(((((x/x)+(x*x)+x))))', 0],
#  ['((((x+x)+((x/x)+(x*x)+(x+x)))))', 0],
#  ['(((((x/x)+x))))', 0],
#  ['(((x/x)+(x-8)))', 0],
#  ['((x+(5-6)+(x*x)+(x+x)))', 0],
#  ['((x+(x*x)+((x/x)+5)))', 0],
#  ['(((x+(x-x)+x)))', 0],
#  ['((((x/x)+9)))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x-x)-(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x+x))))', 0],
#  ['(((1+(x*x)+x)))', 0],
#  ['((((x/x)+4)))', 0],
#  ['((1+(x*x)+(7-8)+(x*x)+(x+x)))', 0],
#  ['((x+(x*x)+((x/x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['(((1*x)-(x+x)/((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+(x*x)+((x/x)+(x*x)+((x/x)+x)))))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x+x)))', 0],
#  ['((x+((x-x)*(7-8))))', 0],
#  ['(((8-x)-(x*x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x+x)/x))))', 0],
#  ['((((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+(x+1)))', 0],
#  ['((1+((x/x)+x)))', 0],
#  ['((((x/x)+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x+x))))', 0],
#  ['((((x-x)-x)))', 0],
#  ['((x+(x*x)+((9/x)+(7-8)+(x*x)+(x+x))))', 0],
#  ['(((1+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x+1))))', 0],
#  ['(((x+x)))', 0],
#  ['((((1*x)-(x*x)+((x/x)+x))))', 0],
#  ['((x*(x*x)+((x/x)+x)))', 0],
#  ['((x+(2/x)+(x/x)))', 0],
#  ['(((1+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x+x))))', 0],
#  ['((((9*x)-(x*x)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/5)+2)))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((x+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+((x/x)+x)))', 0],
#  ['((((x-x)-((x/x)+x))))', 0],
#  ['(((x+(x*x)+(x-8)+(x*x)+(7-8)+(x*x)+x)))', 0],
#  ['((x+(x-x)+((x/x)+x)))', 0],
#  ['((((x+x))))', 0],
#  ['(((x+((x/x)+(x*x)+(x+x)))))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x/x)+(x*x)+((x/x)+x)))', 0],
#  ['(((x/x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x*x)+(x+x)))', 0],
#  ['(((x+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['(((x+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['((x*(2/x)+(x*x)+(x+x)))', 0],
#  ['((x+(7-x)+(x*x)+(x+x)))', 0],
#  ['((((x+(x*x)+x))))', 0],
#  ['(((x+(x*x)+((x/x)+((x/x)+x)))))', 0],
#  ['(((x+(5+9)*((x-5)*(x+3)))))', 0],
#  ['(((((x/x)+x))))', 0],
#  ['(((x+(x*3)+((x/x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+((9/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['((((x+(x*x)+(x*x)+x))))', 0],
#  ['((x+(x*x)+((x/x)+(x*x)+(x+x))))', 0],
#  ['((((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+(x*x)+x)))', 0],
#  ['(((x/x)+(x*x)+(x*x)+(x+x)))', 0],
#  ['((1+(x+x)))', 0],
#  ['(((x-x)-(x*x)+((x/x)+x)))', 0],
#  ['((x+(x+x)))', 0],
#  ['((1+(x*x)+((x/x)+x)))', 0],
#  ['((x+(x*x)+(x+x)))', 0],
#  ['((x+(x*x)+(x*x)+(x-1)))', 0],
#  ['(((x/x)+((x/x)+x)))', 0],
#  ['(((x/x)+((x/x)+(x*x)+((x/x)+x))))', 0],
#  ['(((x+x)))', 0],
#  ['(((x+(x*x)+(x*x)+((x/x)+x))))', 0],
#  ...]
