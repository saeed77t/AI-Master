# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
import seaborn as sn
from scipy import stats
import skfuzzy
from skfuzzy import control as ctrl
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
class PreprocessData:
    def NomalizeData(Data):
        Data=np.array(Data)
        lenght = len(Data)
        normalizedData = []
        
        for i in range (lenght):
            normalizedData.append(float((Data[i] - min(Data) ) / ( max(Data) - min(Data)) ))
            
        return normalizedData
    
    def TestAndTrain(Data , PercentageOfTrainData):
        PercentageOfTrainData = float(PercentageOfTrainData / 100)
        Train_DataFrame = Data.sample(frac=PercentageOfTrainData)
        Test_DataFrame =Data.drop(Train_DataFrame.index)
        
        return Train_DataFrame , Test_DataFrame

# %%
Data = pd.read_excel('Detection of COVID-19 Infection from Routine Blood Exams_dataset.xlsx')
Data["SESSO"].replace({'M': 0.,'F': 1.}, inplace=True)
a = Data[Data['TARGET']==0]
Data["TARGET"].replace({2:1}, inplace=True)
Data['WBC'] = Data['WBC']*100
Data['Linfociti'] = Data['Linfociti']*100
Data['Monociti'] = Data['Monociti']*100
Data['Eosinofili'] = Data['Eosinofili']*100
Data
# Out:
#      SESSO  AGE     WBC  Piastrine  Neutrofili  Linfociti  Monociti  \
# 0      0.0   56   290.0      128.0         1.9       80.0      20.0
# 1      0.0   56   350.0      151.0         2.1       90.0      40.0
# 2      0.0   72   460.0      206.0         NaN        NaN       NaN
# 3      0.0   72  1650.0      316.0        14.0      120.0      30.0
# 4      0.0   77   490.0      198.0         NaN        NaN       NaN
# ..     ...  ...     ...        ...         ...        ...       ...
# 274    1.0   40   560.0      270.0         NaN        NaN       NaN
# 275    0.0   26   470.0       44.0         NaN        NaN       NaN
# 276    1.0   44  1570.0      356.0         NaN        NaN       NaN
# 277    1.0   41  1200.0      321.0         6.7      230.0     160.0
# 278    0.0   53  1790.0      272.0        14.1      210.0     150.0
#
#      Eosinofili  Basofili    PCR   AST   ALT    ALP   GGT    LDH  TARGET
# 0           0.0       0.0   29.0  36.0  18.0   43.0  21.0  257.0       1
# ...

# %%
Data['ALT'].min()
# Out:
# 9.0

# %%
def Suprimun_Tnorm(Relation, data):
    ror = np.vstack((Relation, data))
    sup_norm = np.max(np.min(ror, axis=0))
    return sup_norm


def composition(relation , data):
    composed = np.array(list(map(lambda x: list(map(lambda y: Suprimun_Tnorm(relation[x], data[y]),range(data.shape[0]))),range(relation.shape[0]))))
    return composed


def split_by_class(TrainData):
    Data0 = TrainData[TrainData['TARGET']==0]
    target0 = Data0['TARGET']
    Data0 = Data0.drop('TARGET',axis=1)
    # Data0=(Data0-Data0.min())/(Data0.max()-Data0.min())
    Data1 = TrainData[TrainData['TARGET']==1]
    target1 = Data1['TARGET']
    Data1 = Data1.drop('TARGET',axis=1)
    # Data1=(Data1-Data1.min())/(Data1.max()-Data1.min())
    Data2 = TrainData[TrainData['TARGET']==2]
    target2 = Data2['TARGET']
    Data2 = Data2.drop('TARGET',axis=1)
    # Data2=(Data2-Data2.min())/(Data2.max()-Data2.min())
    return Data0 , Data1, Data2 , target0, target1, target2

# %%
#fill misiing values 
imputer= KNNImputer(n_neighbors=4)
Data = imputer.fit_transform(Data[['SESSO', 'AGE','WBC','Piastrine','Neutrofili','Linfociti','Monociti','Eosinofili','Basofili','PCR','AST','ALT','ALP','GGT','LDH','TARGET']])
Data = pd.DataFrame(Data, columns = ['SESSO', 'AGE','WBC','Piastrine','Neutrofili','Linfociti','Monociti','Eosinofili','Basofili','PCR','AST','ALT','ALP','GGT','LDH','TARGET'])
# Data = pd.concat([Data1, Data2,Data0])

# %%
Data
# Out:
#      SESSO   AGE     WBC  Piastrine  Neutrofili  Linfociti  Monociti  \
# 0      0.0  56.0   290.0      128.0       1.900       80.0      20.0
# 1      0.0  56.0   350.0      151.0       2.100       90.0      40.0
# 2      0.0  72.0   460.0      206.0       3.500       55.0      42.5
# 3      0.0  72.0  1650.0      316.0      14.000      120.0      30.0
# 4      0.0  77.0   490.0      198.0       3.775       67.5      42.5
# ..     ...   ...     ...        ...         ...        ...       ...
# 274    1.0  40.0   560.0      270.0       3.500      167.5      67.5
# 275    0.0  26.0   470.0       44.0       5.400       92.5      37.5
# 276    1.0  44.0  1570.0      356.0      13.150      125.0     137.5
# 277    1.0  41.0  1200.0      321.0       6.700      230.0     160.0
# 278    0.0  53.0  1790.0      272.0      14.100      210.0     150.0
#
#      Eosinofili  Basofili    PCR    AST   ALT     ALP    GGT     LDH  TARGET
# ...

# %%
target = list(Data['TARGET'])
wbc = list(Data['WBC'])
piastrine = list(Data['Piastrine'])
noeutrofill = list(Data['Neutrofili'])
Linfociti = list(Data['Linfociti'])
Monociti = list(Data['Monociti'])
Eosinofili = list(Data['Eosinofili'])
Basofili = list(Data['Basofili'])
PCR = list(Data['PCR'])
AST = list(Data['AST'])
ALT = list(Data['ALT'])
ALP = list(Data['ALP'])
GGT = list(Data['GGT'])
LDH = list(Data['LDH'])
AGE = list(Data['AGE'])

cwbc = stats.pointbiserialr(target, wbc)
cpiastrine = stats.pointbiserialr(target, piastrine)
cnoeutrofill = stats.pointbiserialr(target, noeutrofill)
cLinfociti = stats.pointbiserialr(target, Linfociti)
cMonociti = stats.pointbiserialr(target, Monociti)
cEosinofili = stats.pointbiserialr(target, Eosinofili)
cBasofili = stats.pointbiserialr(target, Basofili)
cPCR = stats.pointbiserialr(target, PCR)
cAST = stats.pointbiserialr(target, AST)
cALT = stats.pointbiserialr(target, ALT)
cALP = stats.pointbiserialr(target, ALP)
cGGT = stats.pointbiserialr(target, GGT)
cLDH = stats.pointbiserialr(target, LDH)
cAGE = stats.pointbiserialr(target, AGE)
print('corolation wbc = ',cwbc[0],'|||||| pval wbc = ',cwbc[1])
print('corolation piastrine = ',cpiastrine[0], ' |||||| pval piastrine = ',cpiastrine[1])
print('corolaion noeutrofill = ',cnoeutrofill[0], ' |||||| pval  noeutrofill = ',cnoeutrofill[1])
print('corolation Linfociti = ',cLinfociti[0], ' |||||| pval Linfociti = ',cLinfociti[1])
print('corolation Monociti = ',cMonociti[0], '  |||||| pval Monociti = ',cMonociti[1])
print('corolation Eosinofili = ',cEosinofili[0],' |||||| pval Eosinofili = ',cEosinofili[1])
print('corolation Basofili = ',cBasofili[0], ' |||||| pval Basofili = ',cBasofili[1])
print('######corolation PCR = ',cPCR[0], ' |||||| pval PCR = ',cPCR[1])
print('######corolation AST = ',cAST[0], ' |||||| pval  AST = ',cAST[1])
print('######corolation ALT = ',cALT[0] , ' |||||| pval ALT = ',cALT[1])
print('######corolation ALP = ',cALP[0], ' |||||| pval ALP = ',cALP[1])
print('######corolation GGT = ',cGGT[0], ' |||||| pval GGT = ',cGGT[1])
print('######corolation LDH = ',cLDH[0], ' |||||| pval LDH = ',cLDH[1])
print('######corolation AGE = ',cAGE[0], ' |||||| pval AGE = ',cAGE[1])
# Out:
# corolation wbc =  -0.19315379527313117 |||||| pval wbc =  0.0011852460064474524
# corolation piastrine =  -0.045659001525092766  |||||| pval piastrine =  0.4474769964029412
# corolaion noeutrofill =  -0.1285552758421598  |||||| pval  noeutrofill =  0.031827477406032416
# corolation Linfociti =  -0.3150368992014245  |||||| pval Linfociti =  7.614108248719836e-08
# corolation Monociti =  -0.27498450409444375   |||||| pval Monociti =  3.120507342842616e-06
# corolation Eosinofili =  -0.2040137843659165  |||||| pval Eosinofili =  0.000606854725026091
# corolation Basofili =  -0.12819360199132807  |||||| pval Basofili =  0.032315901509511594
# ######corolation PCR =  0.21622276584480724  |||||| pval PCR =  0.00027417405438361097
# ######corolation AST =  0.21212250982505995  |||||| pval  AST =  0.0003598195755476327
# ######corolation ALT =  0.20258515992213294  |||||| pval ALT =  0.0006640400278052779
# ######corolation ALP =  -0.03983363355233881  |||||| pval ALP =  0.5075683393674252
# ...

# %%
# Data0 , Data1, Data2 , target0, target1, target2  = split_by_class(TrainData)

# %%
corr = Data.corr()

corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/gv/29bx0dbj5fvf2ql1sq4xwxsh0000gn/T/ipykernel_9219/2020719490.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_09737_row0_col0, #T_09737_row1_col1, #T_09737_row2_col2, #T_09737_row3_col3, #T_09737_row4_col4, #T_09737_row5_col5, #T_09737_row6_col6, #T_09737_row7_col7, #T_09737_row8_col8, #T_09737_row9_col9, #T_09737_row10_col10, #T_09737_row11_col11, #T_09737_row12_col12, #T_09737_row13_col13, #T_09737_row14_col14, #T_09737_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_09737_row0_col1, #T_09737_row1_col10, #T_09737_row2_col13, #T_09737_row4_col12, #T_09737_row9_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_09737_row0_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_09737_row0_col3, #T_09737_row11_col4, #T_09737_row13_col4 {
#   background-color: #7b9ff9;
# ...

# %%
# WBC
# Linfociti
# Monociti
# Eosinofili
# PCR
# AST
# ALT
# LDH

# %%
# Datasetreduced = pd.DataFrame(Data, columns = ['WBC','Linfociti','Monociti','Eosinofili','PCR','AST','ALT','LDH','TARGET'])
Datasetreduced = pd.DataFrame(Data, columns = ['WBC','Linfociti','Monociti','Eosinofili','AST','ALT','LDH','TARGET'])

Datasetreduced
# Out:
#         WBC  Linfociti  Monociti  Eosinofili    AST   ALT     LDH  TARGET
# 0     290.0       80.0      20.0         0.0  36.00  18.0  257.00     1.0
# 1     350.0       90.0      40.0         0.0  25.00  14.0  207.00     1.0
# 2     460.0       55.0      42.5         0.0  31.00  22.0  384.75     1.0
# 3    1650.0      120.0      30.0         0.0  96.00  33.0  651.00     1.0
# 4     490.0       67.5      42.5         0.0  35.75  24.5  330.00     1.0
# ..      ...        ...       ...         ...    ...   ...     ...     ...
# 274   560.0      167.5      67.5         2.5  22.00  29.0  233.25     0.0
# 275   470.0       92.5      37.5         0.0  30.00  44.0  175.00     0.0
# 276  1570.0      125.0     137.5         2.5  31.00  17.0  272.00     0.0
# 277  1200.0      230.0     160.0       130.0  16.00  11.0  266.00     0.0
# 278  1790.0      210.0     150.0        20.0  13.00  10.0  258.00     0.0
#
# [279 rows x 8 columns]

# %%
#split to teset and train 
# Dataset1 = PreprocessData.NomalizeData(Data)
Dataset = PreprocessData.TestAndTrain(Datasetreduced , 80)

Datas = Dataset[0]
TestData = Dataset[1]
targetTest = TestData['TARGET']
TestData = TestData.drop('TARGET',axis=1)
# TestData=(TestData-TestData.min())/(TestData.max()-TestData.min())

# %%
plt.matshow(Datas.corr())
plt.show()

# %%
memberships = []
fuzzyfiedsets = []

# %%
wbc= list(Datas['WBC'])

plt.figure()
plt.hist(wbc,edgecolor="white")
plt.show()
#Normal range  for adult 4 to 10 data scaled to 100 -> 400 to 1000
#fuzzyfuy wbc : 
# dom = max(WBC) - min(WBC)
dom = np.arange(0, max(wbc),1)

wbclow = skfuzzy.membership.trimf(dom ,[0,0,450] )
wbcnormal= skfuzzy.membership.trimf(dom ,[400,700,1100] )
wbchigh = skfuzzy.membership.trimf(dom ,[1000,max(wbc),max(wbc)])
fuzzyfiedsets.append([wbclow,wbcnormal,wbchigh])


WBC = ctrl.Antecedent(np.arange(0, max(wbc)), 'WBC')
WBC['low'] = skfuzzy.membership.trimf(dom ,[0,0,450] )
WBC['normal']= skfuzzy.membership.trimf(dom ,[400,700,1100] )
WBC['high'] = skfuzzy.membership.trimf(dom ,[1000,max(wbc),max(wbc)])
memberships.append([WBC['low'] , WBC['normal'] ,WBC['high']])


plt.figure()
plt.plot(wbclow , 'b',label='low')
plt.plot(wbcnormal , 'g',label='normal')
plt.plot(wbchigh , 'r',label='high')
# plt.xticks(np.arange(0,60,5))
plt.title('memebership of feature WBC')
plt.legend()
plt.show()

# print(wbc.universe)


WBC.view()
# FWBC = ctrl.Antecedent(dom,'FWBC')
# FWBC.automf(3 ,names=['Low','Normal','High'])
# FWBC.view()
# type(FWBC['Low'])
# Out:
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
lnf = list(Datas['Linfociti'])
plt.figure()
plt.hist(lnf,edgecolor="white")
plt.show()

#Normal range  for adult 1.2 to 3 Data set scald to 100x so from 120 to 300 is normal range
#fuzzyfuy linfocit : 
# dom = max(WBC) - min(WBC)
dom = np.arange(0, max(lnf),1)
lnflow = skfuzzy.membership.trimf(dom ,[0,0,130] )
lnfnormal = skfuzzy.membership.trimf(dom ,[100,160,300] )
lnfhigh = skfuzzy.membership.trimf(dom ,[270,max(lnf),max(lnf)])
fuzzyfiedsets.append([lnflow,lnfnormal,lnfhigh])

Linfociti = ctrl.Antecedent(np.arange(0, max(lnf)), 'Linfociti')
Linfociti['low']  = skfuzzy.membership.trimf(dom ,[0,0,130] )
Linfociti['normal'] = skfuzzy.membership.trimf(dom ,[100,160,300] )
Linfociti['high'] = skfuzzy.membership.trimf(dom ,[270,max(lnf),max(lnf)])

memberships.append([Linfociti['low'] , Linfociti['normal'] ,Linfociti['high']])


plt.figure()
plt.plot(lnflow , 'b',label='low')
plt.plot(lnfnormal , 'g',label='normal')
plt.plot(lnfhigh , 'r',label='high')
# plt.xticks(np.arange(0,4,0.1))
plt.title('memebership of feature linfociti ')
plt.legend()
plt.show()

Linfociti.view()
# Out:
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
mnc = list(Datas['Monociti'])

plt.figure()
plt.hist(mnc,edgecolor="white")
plt.show()

#Normal range  for adult 0.2 to 0.7 Data set scald to 100x so from 20 to 70 is normal range
#fuzzyfuy Monociti : 
dom = np.arange(0, max(mnc),1)
mnclow = skfuzzy.membership.trimf(dom ,[min(mnc),min(mnc),20] )
mncnormal = skfuzzy.membership.trimf(dom ,[20,50,70] )
mnchigh = skfuzzy.membership.trimf(dom ,[60,max(mnc),max(mnc)])
fuzzyfiedsets.append([mnclow , mncnormal ,mnchigh])


Monociti = ctrl.Antecedent(np.arange(0, max(mnc)), 'Monociti')
Monociti['low'] = skfuzzy.membership.trimf(dom ,[min(mnc),min(mnc),20] )
Monociti['normal'] = skfuzzy.membership.trimf(dom ,[20,50,70] )
Monociti['high'] = skfuzzy.membership.trimf(dom ,[60,max(mnc),max(mnc)])
memberships.append([Monociti['low'] , Monociti['normal'] ,Monociti['high']])





plt.figure()
plt.plot(mnclow , 'b',label='low')
plt.plot(mncnormal , 'g',label='normal')
plt.plot(mnchigh , 'r',label='high')
# plt.xticks(np.arange(0,4,0.1))
plt.title('memebership of feature Monociti ')
plt.legend()
plt.show()

Monociti.view()
# Out:
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
esnf = list(Datas['Eosinofili'])

plt.figure()
plt.hist(esnf,edgecolor="white")
# plt.xticks(np.arange(0,1,0.1))
plt.xlim()
plt.show()
#Normal range  for adult 0.1 to 0.3 Data set scald to 100x so from 10 to 30is normal range
#fuzzyfuy Eosinofili : 
dom = np.arange(0, max(esnf),1)
esnflow = skfuzzy.membership.trimf(dom ,[min(esnf),min(esnf),18] )
esnfnormal = skfuzzy.membership.trimf(dom ,[10,20,30] )
esnfhigh = skfuzzy.membership.trimf(dom ,[25,max(esnf),max(esnf)])
fuzzyfiedsets.append([esnflow , esnfnormal ,esnfhigh])

Eosinofili = ctrl.Antecedent(np.arange(0, max(esnf)), 'Eosinofili')
Eosinofili['low']  = skfuzzy.membership.trimf(dom ,[min(esnf),min(esnf),18] )
Eosinofili['normal'] = skfuzzy.membership.trimf(dom ,[10,20,30] )
Eosinofili['high']  = skfuzzy.membership.trimf(dom ,[25,max(esnf),max(esnf)])
memberships.append([Eosinofili['low'] , Eosinofili['normal'] ,Eosinofili['high'] ])




plt.figure()
plt.plot(esnflow , 'b',label='low')
plt.plot(esnfnormal , 'g',label='normal')
plt.plot(esnfhigh , 'r',label='high')
plt.title('memebership of feature Eosinofili ')
plt.legend()
plt.show()

Eosinofili.view()
# Out:
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# pcr = list(Datas['PCR'])

# plt.figure()
# plt.hist(pcr,edgecolor="white")
# plt.xlim()
# # plt.xticks(np.arange(0,800,20))
# plt.show()

# # normal  range is 0 - 90 
# #fuzzyfuy PCR : 
# dom = np.arange(0, max(pcr),1)
# pcrlow = skfuzzy.membership.trimf(dom ,[0,0,0] )
# pcrnormal = skfuzzy.membership.trimf(dom ,[0,40,100] )
# pcrhigh = skfuzzy.membership.trimf(dom ,[70,max(pcr),max(pcr)])
# # fuzzyfiedsets.append([pcrlow , pcrnormal ,pcrhigh])


# # PCR = ctrl.Antecedent(np.arange(0, max(pcr)), 'PCR')

# # PCR['low'] = skfuzzy.membership.trimf(dom ,[0,0,0] )
# # PCR['normal'] = skfuzzy.membership.trimf(dom ,[0,40,100] )
# # PCR['high'] = skfuzzy.membership.trimf(dom ,[70,max(pcr),max(pcr)])


# # memberships.append([PCR['low'] , PCR['normal'] ,PCR['high'] ])






# plt.figure()
# plt.plot(pcrlow , 'b',label='low')
# plt.plot(pcrnormal , 'g',label='normal')
# plt.plot(pcrhigh , 'r',label='high')
# plt.title('memebership of feature PCR ')
# plt.legend()
# plt.show()

# # PCR.view()

# %%
ast = list(Datas['AST'])

plt.figure()
plt.hist(ast,edgecolor="white")
plt.xlim()
plt.show()
# normal range  8 - 48 
#fuzzyfuy AST : 
dom = np.arange(0, max(ast),1)
astlow = skfuzzy.membership.trimf(dom ,[0,0,10] )
astnormal = skfuzzy.membership.trimf(dom ,[6,26,48] )
asthigh = skfuzzy.membership.trimf(dom ,[40,max(ast),max(ast)])
fuzzyfiedsets.append([astlow , astnormal ,asthigh])



AST = ctrl.Antecedent(np.arange(0, max(ast)), 'AST')

AST['low'] = skfuzzy.membership.trimf(dom ,[0,0,10] )
AST['normal'] = skfuzzy.membership.trimf(dom ,[6,26,48] )
AST['high'] = skfuzzy.membership.trimf(dom ,[40,max(ast),max(ast)])
memberships.append([AST['low'] , AST['normal'] ,AST['high']])






plt.figure()
plt.plot(astlow , 'b',label='low')
plt.plot(astnormal , 'g',label='normal')
plt.plot(asthigh , 'r',label='high')
plt.title('memebership of feature AST ')
plt.legend()
plt.show()

AST.view()
# Out:
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
alt = list(Datas['ALT'])

plt.figure()
plt.hist(alt,edgecolor="white")
plt.xlim()
plt.show()
# normal range 7 - 55 
#fuzzyfuy ALT : 
dom = np.arange(0, max(alt),1)
altlow = skfuzzy.membership.trimf(dom ,[0,0,10] )
altnormal = skfuzzy.membership.trimf(dom ,[6,31,55] )
althigh = skfuzzy.membership.trimf(dom ,[50,max(alt),max(alt)])
fuzzyfiedsets.append([altlow , altnormal ,althigh])




ALT = ctrl.Antecedent(np.arange(0, max(alt)), 'ALT')

ALT['low'] = skfuzzy.membership.trimf(dom ,[0,0,10] )
ALT['normal'] = skfuzzy.membership.trimf(dom ,[6,31,55] )
ALT['high'] = skfuzzy.membership.trimf(dom ,[50,max(alt),max(alt)])
memberships.append([ALT['low'] , ALT['normal'] ,ALT['high']])



plt.figure()
plt.plot(altlow , 'b',label='low')
plt.plot(altnormal , 'g',label='normal')
plt.plot(althigh , 'r',label='high')
plt.title('memebership of feature ALT ')
plt.legend()
plt.show()

ALT.view()
# Out:
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
ldh = list(Datas['LDH'])

plt.figure()
plt.hist(ldh,edgecolor="white")
plt.xlim()
plt.show()
#normal 100 to 500 
#fuzzyfuy LDH : 
dom = np.arange(0, max(ldh),1)
ldhlow = skfuzzy.membership.trimf(dom ,[0,0,110] )
ldhnormal = skfuzzy.membership.trimf(dom ,[90,300,510] )
ldhhigh = skfuzzy.membership.trimf(dom ,[450,max(ldh),max(ldh)])
fuzzyfiedsets.append([ldhlow , ldhnormal ,ldhhigh])




# LDH = ctrl.Antecedent(np.arange(0, max(ldh)), 'LDH')
LDH = ctrl.Antecedent(dom, 'LDH')

LDH['low'] = skfuzzy.membership.trimf(dom ,[0,0,110] )
LDH['normal'] = skfuzzy.membership.trimf(dom ,[90,300,510] )
LDH['high'] = skfuzzy.membership.trimf(dom ,[450,max(ldh),max(ldh)])
memberships.append([LDH['low'] , LDH['normal'] ,LDH['high']])





plt.figure()
plt.plot(ldhlow , 'b',label='low')
plt.plot(ldhnormal , 'g',label='normal')
plt.plot(ldhhigh , 'r',label='high')
plt.title('memebership of feature LDH ')
plt.legend()
plt.show()

LDH.view()
# Out:
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fuzzyfiedtarget = []

trg = list(Datas['TARGET'])




dom = np.arange(0, max(trg),0.1)
TARGET = ctrl.Consequent(np.arange(0, max(trg),0.1), 'TARGET')

TARGET['sick'] = skfuzzy.membership.trimf(dom ,[0.3,1,1])
TARGET['well'] = skfuzzy.membership.trimf(dom,[0,0.3,0.3])
memberships.append( [TARGET['well'] , TARGET['sick']])

TARGETsick = skfuzzy.membership.trimf(dom ,[0.3,1,1])
TARGETwel = skfuzzy.membership.trimf(dom,[0,0.3,0.3])
fuzzyfiedtarget.append( [TARGETwel, TARGETsick])

plt.figure()
plt.hist(trg,edgecolor="white")
plt.xlim()
plt.show()


plt.figure()
plt.plot(TARGETsick , 'r',label='sick')
plt.plot(TARGETwel , 'g',label='well')
# plt.plot(ldhhigh , 'r',label='high')
plt.title('memebership of feature target ')
plt.legend()
plt.show()

TARGET.view()
# Out:
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
a = np.array(fuzzyfiedsets,dtype=object)
print(a.shape)
memberships
b = np.array(memberships,dtype=object)
print(b.shape)
b
# Out:
# (7, 3)
# (8,)
# array([list([WBC[low], WBC[normal], WBC[high]]),
#        list([Linfociti[low], Linfociti[normal], Linfociti[high]]),
#        list([Monociti[low], Monociti[normal], Monociti[high]]),
#        list([Eosinofili[low], Eosinofili[normal], Eosinofili[high]]),
#        list([AST[low], AST[normal], AST[high]]),
#        list([ALT[low], ALT[normal], ALT[high]]),
#        list([LDH[low], LDH[normal], LDH[high]]),
#        list([TARGET[well], TARGET[sick]])], dtype=object)

# %%
AllRules = []
PosetiveRules =[]
NegativeRules = []
for  row  in  Datas.iterrows():
    rule=[]
    for  i , c in enumerate(Datas.columns):
        if(i !=7):
            dom = np.arange(0, Datas[c].max() ,1)

            lowship = skfuzzy.interp_membership(dom ,fuzzyfiedsets[i][0],row[1][c])
            normalship = skfuzzy.interp_membership(dom ,fuzzyfiedsets[i][1],row[1][c])
            highship = skfuzzy.interp_membership(dom ,fuzzyfiedsets[i][2],row[1][c])
            rule.append(np.argmax([lowship , normalship , highship]))
    rule.append(row[1]['TARGET'])
    if (rule in AllRules):
        continue
    AllRules.append(rule)
    if(row[1]['TARGET'] == 1):
        PosetiveRules.append(rule)
    else:
        NegativeRules.append(rule)

# %%
m = np.array(AllRules)

# %%
m.shape
# Out:
# (100, 8)

# %%
# AllRules

# %%
def defineRule(AllRules , memberships,fuzzyfiedsets):
    rules = []
    for i in range (len(AllRules)):
        rl = []
        for j in range(len(AllRules[i])):
            # print(type(AllRules[i][j]))
            rl.append(memberships[j][int(AllRules[i][j])])
        rules.append(rl)
    return rules

# %%
def setrules(rules):
    label_rules = []
    for i in range(len(rules)):
        rule = ctrl.Rule(rules[i][0] & rules[i][1] & rules[i][2] & rules[i][3] & rules[i][4] & rules[i][5]& rules[i][6]  , rules[i][7] )
        label_rules.append(rule)
    return label_rules

# %%
rules = defineRule(AllRules,memberships,fuzzyfiedsets)
rules[1]
# Out:
# [WBC[normal],
#  Linfociti[normal],
#  Monociti[high],
#  Eosinofili[normal],
#  AST[normal],
#  ALT[normal],
#  LDH[normal],
#  TARGET[sick]]

# %%
label_rules = setrules(rules)

# %%
# AllRules

# %%
label_rules[0].view()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %%
tipping_ctrl = ctrl.ControlSystem(label_rules)

# %%
label_result = ctrl.ControlSystemSimulation(tipping_ctrl)

# %%
tipping_ctrl.view_n()
# Out:
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/controlsystem.py:140: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
count = 0
predict = []
norl = []
for j, test in TestData.iterrows():
    count = count+1
    label_result.input['WBC'] = test['WBC']
    label_result.input['Linfociti'] = test['Linfociti']
    label_result.input['Monociti'] = test['Monociti']
    label_result.input['Eosinofili'] = test['Eosinofili']
    # label_result.input['PCR'] = test['PCR']
    label_result.input['AST'] = test['AST']
    label_result.input['ALT'] = test['ALT']
    label_result.input['LDH'] = test['LDH']
    try:

        label_result.compute()
        
        predict.append(label_result.output['TARGET'])
        if (j % 5 == 0 ):
            TARGET.view(sim=label_result)
        
    except:
        predict.append(-1)
print(predict)
# Out:
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /Users/saeed/opt/anaconda3/lib/python3.9/site-packages/skfuzzy/control/fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
# ...

# %%
dom = np.arange(0, max(trg),0.1)

# %%
def prediction(predict , fuzzyfiedtarget):
    pred = []
    for i in range (len(predict)):
        if(predict[i]!= -1):
            targtsick  = skfuzzy.interp_membership(dom ,fuzzyfiedtarget[0][1],predict[i])
            targtwell  = skfuzzy.interp_membership(dom ,fuzzyfiedtarget[0][0],predict[i])
            if(targtsick > targtwell):
                pred.append(1)
            else:
                pred.append(0)
        else:
            pred.append(1)
    return pred

# %%
predicted = prediction(predict , fuzzyfiedtarget)

# %%
accuracy_score(targetTest, predicted)
# Out:
# 0.6964285714285714

# %%
conf2=confusion_matrix(targetTest,predicted)

# %%
df_cm = pd.DataFrame(conf2, range(2), range(2))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size":18} , cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
a = np.array(fuzzyfiedtarget)
a.shape
# Out:
# (1, 2, 10)

# %%
a[0].shape
# Out:
# (2, 10)
