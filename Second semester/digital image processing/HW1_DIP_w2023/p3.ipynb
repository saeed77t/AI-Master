# %%
import cv2
import glob
import matplotlib.pyplot as plt
import numpy as np
import skimage
import scipy.ndimage

# %%
img = cv2.imread('imgs/digital_images.jpg')

# %%
img[:,:,0].shape
# Out:
# (359, 479)

# %%
plt.imshow(img)
plt.show()

# %%
scipy.ndimage.convolve(img,filter,'near')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 scipy.ndimage.convolve(img,filter,'near')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/ndimage/filters.py:858, in convolve(input, weights, output, mode, cval, origin)
#     756 @_ni_docstrings.docfiller
#     757 def convolve(input, weights, output=None, mode='reflect', cval=0.0,
#     758              origin=0):
#     759     """
#     760     Multidimensional convolution.
#     761
#    (...)
#     856
#     857     """
# --> 858     return _correlate_or_convolve(input, weights, output, mode, cval,
#     859                                   origin, True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/scipy/ndimage/filters.py:659, in _correlate_or_convolve(input, weights, output, mode, cval, origin, convolution)
# ...
